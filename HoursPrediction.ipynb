# %%
import pandas as pd
import numpy as np
import datetime as dt
from dateutil.parser import parse
from sklearn.model_selection import train_test_split
#from xgboost import XGBRegressor
from datetime import datetime
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from datetime import datetime, timedelta

# Store our trained model using joblib
import joblib
from sklearn import tree

# %%
data = pd.read_csv('production.csv')
data = data.drop_duplicates()
data.info()
data.plot()
# data = pd.DataFrame(data)
# data = data.drop('AMOUNT_COMPLETED', axis=1) # to drop a column
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 0 to 134
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   STARTDATE       125 non-null    object
#  1   AMOUNT_TO_CUT   125 non-null    int64
#  2   ENDDATE         125 non-null    object
#  3   AMOUNT_OF_DAYS  125 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 4.9+ KB
#       STARTDATE  AMOUNT_TO_CUT     ENDDATE  AMOUNT_OF_DAYS
# 0      7/8/2022             25   7/20/2022              12
# 1     9/19/2022             25   9/30/2022              11
# 2     5/24/2022           2580  12/10/2022             200
# 3      5/8/2022             12   5/16/2022               9
# 4     6/12/2022             22   6/24/2022              13
# ..          ...            ...         ...             ...
# 130  10/12/2022             35  10/15/2022               4
# 131  10/17/2022             60  10/15/2022               4
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Read the CSV file
data = pd.read_csv('production.csv')

# Extract the "AMOUNT_TO_CUT" and "AMOUNT_OF_DAYS" columns into arrays
amount_to_cut = data['AMOUNT_TO_CUT'].values.reshape(-1, 1)
amount_of_days = data['AMOUNT_OF_DAYS']

# Print the extracted arrays
# print("AMOUNT_TO_CUT:", amount_to_cut)
# print("AMOUNT_OF_DAYS:", amount_of_days)

# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(amount_to_cut, amount_of_days)

# Input the amount to cut
input_amount_to_cut = float(input("Enter the amount to cut: "))

# Predict the number of days based on the input amount
predicted_days = model.predict([[input_amount_to_cut]])

# Print the predicted number of days
print("Predicted number of days to cut {} piece(s): {:.2f}".format(input_amount_to_cut, predicted_days[0]))
# Out:
# Enter the amount to cut: 200
# Predicted number of days to cut 200.0 piece(s): 35.26
